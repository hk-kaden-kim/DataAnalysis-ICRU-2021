# %% [markdown]
# # ICRU 2021 Data Analysis

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt;
import seaborn as sns

# %% [markdown]
# ## File Import
# Req. Libraries
# - xlrd 2.0.1 (Library for developers to extract data from Microsoft Excel (tm) .xls spreadsheet files)
# - openpyxl 3.0.9 (A Python library to read/write Excel 2010 xlsx/xlsm files)
#
# File Name
# - icru_2021_data_sheet0 : (원본)ICRU데이터_rev1_220108_테스트.xlsx / Sheet0
# - icru_2021_data_sheet1 : (원본)ICRU데이터_rev1_220108_테스트.xlsx / Sheet1

# %%
icru_2021_data_sheet0 = pd.read_excel('(원본)ICRU데이터_rev1_220108_테스트.xlsx',sheet_name=0,index_col=False)
icru_2021_data_sheet1 = pd.read_excel('(원본)ICRU데이터_rev1_220108_테스트.xlsx',sheet_name=1,index_col=False)
# icru_2021_data_sheet0.info()
# icru_2021_data_sheet1.info()

# %% [markdown]
# ## Cleansing
#
# sheet0 [2162 rows x 16 columns]
# - id(int)
# - type(category)
# - gender(Binary) : 1(남성), 0(여성)
# - year(int)
# - work1-3(category)
# - expF1-9(category)
#
# sheet1 [2160 rows x 38 columns]
# - id(int)
# - type(category)
# - F1-9_R, F1-9_E, F1-9_A, F1-9_D (int)

# %%
'''
A. icru_2021_data_sheet0
_column index
    id(int)
    type(category)
    gender(Binary) : 1(남성), 0(여성)
    year(int)
    work1-3(category) 
    expF1-9(category)
'''
sheet0 = icru_2021_data_sheet0.copy()
### Delete '테스트' data
col = sheet0.columns[1]
for key in ['테스트','d']:
    testRow = sheet0[sheet0[col]==key].index
    sheet0.drop(testRow,inplace=True)

### Column Clean-UP
sheet0.drop(sheet0.columns[16:], axis=1, inplace=True)
sheet0.drop(sheet0.columns[1], axis=1, inplace=True)
orgColumn = list(sheet0.columns)
renamedColumn = ['id', 'gender', 'year',
                'work1', 'work2', 'work3',
                'expF1', 'expF2', 'expF3', 'expF4', 'expF5', 'expF6', 'expF7', 'expF8', 'expF9']
sheet0.columns = renamedColumn
columnRef0 = np.array([renamedColumn,orgColumn]).transpose()

### Row Clean-UP
sheet0['gender'] = sheet0['gender'].map({'남':1,'여':0}).astype('boolean')
sheet0['year'] = sheet0['year'].astype('int64')

# %%
'''
B. icru_2021_data_sheet1
_column index
    id(int)
    F1-9_R, F1-9_E, F1-9_A, F1-9_D (int)
    type(char) : 12 types
'''
sheet1 = icru_2021_data_sheet1.copy()
### Delete '테스트' data
sheet1.drop([0], axis=0, inplace=True)
col = sheet1.columns[1]
for key in ['테스트','d']:
    testRow = sheet1[sheet1[col]==key].index
    sheet1.drop(testRow,inplace=True)

### Column Clean-UP
sheet1.drop(sheet1.columns[-1], axis=1, inplace=True)
sheet1.drop(sheet1.columns[38:50], axis=1, inplace=True)
sheet1.drop(sheet1.columns[1], axis=1, inplace=True)
sheet1 = sheet1[:2160]
orgColumn = list(sheet1.columns)
renamedColumn =['id',
                'F1_R', 'F1_E', 'F1_A', 'F1_D',
                'F2_R', 'F2_E', 'F2_A', 'F2_D',
                'F3_R', 'F3_E', 'F3_A', 'F3_D',
                'F4_R', 'F4_E', 'F4_A', 'F4_D',
                'F5_R', 'F5_E', 'F5_A', 'F5_D',
                'F6_R', 'F6_E', 'F6_A', 'F6_D',
                'F7_R', 'F7_E', 'F7_A', 'F7_D',
                'F8_R', 'F8_E', 'F8_A', 'F8_D',
                'F9_R', 'F9_E', 'F9_A', 'F9_D',
                'type']
sheet1.columns = renamedColumn
columnRef1 = np.array([renamedColumn,orgColumn]).transpose()
sheet1.reset_index(drop=True, inplace=True)

### Row Clean-UP
for col in sheet1.columns[:-1]:
    sheet1[col] = sheet1[col].astype('int64')
sheet1['type'] = sheet1['type'].astype('category')

# %%
# move and add 'type' column next to 'id'
sheet0 = pd.concat([sheet0,sheet1['type']], axis=1)
sheet0 = sheet0[['id', 'type', 
                'gender', 'year',
                'work1', 'work2', 'work3',
                'expF1', 'expF2', 'expF3', 'expF4', 'expF5', 'expF6', 'expF7', 'expF8', 'expF9']]
sheet1 = sheet1[['id','type',
                'F1_R', 'F1_E', 'F1_A', 'F1_D',
                'F2_R', 'F2_E', 'F2_A', 'F2_D',
                'F3_R', 'F3_E', 'F3_A', 'F3_D',
                'F4_R', 'F4_E', 'F4_A', 'F4_D',
                'F5_R', 'F5_E', 'F5_A', 'F5_D',
                'F6_R', 'F6_E', 'F6_A', 'F6_D',
                'F7_R', 'F7_E', 'F7_A', 'F7_D',
                'F8_R', 'F8_E', 'F8_A', 'F8_D',
                'F9_R', 'F9_E', 'F9_A', 'F9_D']]

# %% [markdown]
# ## Analysis

# %% [markdown]
# ### Case1
# Heatmap of READ types in Features (F1~F9)
# - 2. READ 분석: 질문별 R,E,A,D 분포를 통해서 질문의 Quality를 파악할 수 있을 거 같음

# %%
def featureAnalysis(FeatureName):
    featureCol = ['id','type']

    df_result = pd.DataFrame()
    substring = FeatureName
    for col in sheet1.columns:
        if substring in col:
            featureCol.append(col)
    df = sheet1[featureCol]

    df_typeFiltered = df[df['type'].isin(['RE','RA','RD'])]
    df_result['typeR'] = df_typeFiltered[featureCol[-4:]].mean()

    df_typeFiltered = df[df['type'].isin(['ER','EA','ED'])]
    df_result['typeE'] = df_typeFiltered[featureCol[-4:]].mean()

    df_typeFiltered = df[df['type'].isin(['AR','AE','AD'])]
    df_result['typeA'] = df_typeFiltered[featureCol[-4:]].mean()

    df_typeFiltered = df[df['type'].isin(['DR','DE','DA'])]
    df_result['typeD'] = df_typeFiltered[featureCol[-4:]].mean()

    return df_result

# %%
df = featureAnalysis('F1')
df.style.background_gradient(cmap='Greens',vmin = 0, vmax = 4, axis = None)
# Out:
# <style  type="text/css" >
# #T_38a39_row0_col0{
#             background-color:  #016e2d;
#             color:  #f1f1f1;
#         }#T_38a39_row0_col1{
#             background-color:  #349d53;
#             color:  #000000;
#         }#T_38a39_row0_col2{
#             background-color:  #339c52;
#             color:  #000000;
#         }#T_38a39_row0_col3{
#             background-color:  #6dc072;
#             color:  #000000;
#         }#T_38a39_row1_col0{
#             background-color:  #1c8540;
#             color:  #000000;
#         }#T_38a39_row1_col1{
#             background-color:  #005622;
#             color:  #f1f1f1;
#         }#T_38a39_row1_col2{
#             background-color:  #228a44;
#             color:  #000000;
#         }#T_38a39_row1_col3{
#             background-color:  #00692a;
#             color:  #f1f1f1;
#         }#T_38a39_row2_col0{
#             background-color:  #78c679;
#             color:  #000000;
#         }#T_38a39_row2_col1{
#             background-color:  #86cc85;
#             color:  #000000;
#         }#T_38a39_row2_col2{
#             background-color:  #4bb062;
#             color:  #000000;
#         }#T_38a39_row2_col3,#T_38a39_row3_col2{
#             background-color:  #7fc97f;
#             color:  #000000;
#         }#T_38a39_row3_col0{
#             background-color:  #a4da9e;
#             color:  #000000;
#         }#T_38a39_row3_col1{
#             background-color:  #90d18d;
#             color:  #000000;
#         }#T_38a39_row3_col3{
#             background-color:  #3fa95c;
#             color:  #000000;
#         }</style><table id="T_38a39_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >typeR</th>        <th class="col_heading level0 col1" >typeE</th>        <th class="col_heading level0 col2" >typeA</th>        <th class="col_heading level0 col3" >typeD</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_38a39_level0_row0" class="row_heading level0 row0" >F1_R</th>
#                         <td id="T_38a39_row0_col0" class="data row0 col0" >3.470588</td>
#                         <td id="T_38a39_row0_col1" class="data row0 col1" >2.713087</td>
#                         <td id="T_38a39_row0_col2" class="data row0 col2" >2.723232</td>
#                         <td id="T_38a39_row0_col3" class="data row0 col3" >2.067568</td>
#             </tr>
#             <tr>
#                         <th id="T_38a39_level0_row1" class="row_heading level0 row1" >F1_E</th>
#                         <td id="T_38a39_row1_col0" class="data row1 col0" >3.107843</td>
#                         <td id="T_38a39_row1_col1" class="data row1 col1" >3.778523</td>
#                         <td id="T_38a39_row1_col2" class="data row1 col2" >3.007071</td>
#                         <td id="T_38a39_row1_col3" class="data row1 col3" >3.532432</td>
#             </tr>
#             <tr>
#                         <th id="T_38a39_level0_row2" class="row_heading level0 row2" >F1_A</th>
#                         <td id="T_38a39_row2_col0" class="data row2 col0" >1.960784</td>
#                         <td id="T_38a39_row2_col1" class="data row2 col1" >1.808725</td>
#                         <td id="T_38a39_row2_col2" class="data row2 col2" >2.393939</td>
#                         <td id="T_38a39_row2_col3" class="data row2 col3" >1.875676</td>
#             </tr>
#             <tr>
#                         <th id="T_38a39_level0_row3" class="row_heading level0 row3" >F1_D</th>
#                         <td id="T_38a39_row3_col0" class="data row3 col0" >1.460784</td>
#                         <td id="T_38a39_row3_col1" class="data row3 col1" >1.699664</td>
#                         <td id="T_38a39_row3_col2" class="data row3 col2" >1.875758</td>
#                         <td id="T_38a39_row3_col3" class="data row3 col3" >2.524324</td>
#             </tr>
#     </tbody></table>

# %%
df = featureAnalysis('F2')
df.style.background_gradient(cmap='Greens',vmin = 0, vmax = 4, axis = None)
# Out:
# <style  type="text/css" >
# #T_3fc7d_row0_col0{
#             background-color:  #19833e;
#             color:  #f1f1f1;
#         }#T_3fc7d_row0_col1{
#             background-color:  #43ac5e;
#             color:  #000000;
#         }#T_3fc7d_row0_col2{
#             background-color:  #53b466;
#             color:  #000000;
#         }#T_3fc7d_row0_col3{
#             background-color:  #55b567;
#             color:  #000000;
#         }#T_3fc7d_row1_col0{
#             background-color:  #99d595;
#             color:  #000000;
#         }#T_3fc7d_row1_col1{
#             background-color:  #65bd6f;
#             color:  #000000;
#         }#T_3fc7d_row1_col2{
#             background-color:  #9cd797;
#             color:  #000000;
#         }#T_3fc7d_row1_col3{
#             background-color:  #a8dca2;
#             color:  #000000;
#         }#T_3fc7d_row2_col0{
#             background-color:  #339c52;
#             color:  #000000;
#         }#T_3fc7d_row2_col1{
#             background-color:  #2a924a;
#             color:  #000000;
#         }#T_3fc7d_row2_col2{
#             background-color:  #0b7734;
#             color:  #f1f1f1;
#         }#T_3fc7d_row2_col3{
#             background-color:  #248c46;
#             color:  #000000;
#         }#T_3fc7d_row3_col0{
#             background-color:  #3ea75a;
#             color:  #000000;
#         }#T_3fc7d_row3_col1{
#             background-color:  #42ab5d;
#             color:  #000000;
#         }#T_3fc7d_row3_col2{
#             background-color:  #309950;
#             color:  #000000;
#         }#T_3fc7d_row3_col3{
#             background-color:  #0c7735;
#             color:  #f1f1f1;
#         }</style><table id="T_3fc7d_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >typeR</th>        <th class="col_heading level0 col1" >typeE</th>        <th class="col_heading level0 col2" >typeA</th>        <th class="col_heading level0 col3" >typeD</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_3fc7d_level0_row0" class="row_heading level0 row0" >F2_R</th>
#                         <td id="T_3fc7d_row0_col0" class="data row0 col0" >3.137255</td>
#                         <td id="T_3fc7d_row0_col1" class="data row0 col1" >2.469799</td>
#                         <td id="T_3fc7d_row0_col2" class="data row0 col2" >2.325253</td>
#                         <td id="T_3fc7d_row0_col3" class="data row0 col3" >2.297297</td>
#             </tr>
#             <tr>
#                         <th id="T_3fc7d_level0_row1" class="row_heading level0 row1" >F2_E</th>
#                         <td id="T_3fc7d_row1_col0" class="data row1 col0" >1.593137</td>
#                         <td id="T_3fc7d_row1_col1" class="data row1 col1" >2.152685</td>
#                         <td id="T_3fc7d_row1_col2" class="data row1 col2" >1.555556</td>
#                         <td id="T_3fc7d_row1_col3" class="data row1 col3" >1.410811</td>
#             </tr>
#             <tr>
#                         <th id="T_3fc7d_level0_row2" class="row_heading level0 row2" >F2_A</th>
#                         <td id="T_3fc7d_row2_col0" class="data row2 col0" >2.720588</td>
#                         <td id="T_3fc7d_row2_col1" class="data row2 col1" >2.887584</td>
#                         <td id="T_3fc7d_row2_col2" class="data row2 col2" >3.343434</td>
#                         <td id="T_3fc7d_row2_col3" class="data row2 col3" >2.970270</td>
#             </tr>
#             <tr>
#                         <th id="T_3fc7d_level0_row3" class="row_heading level0 row3" >F2_D</th>
#                         <td id="T_3fc7d_row3_col0" class="data row3 col0" >2.549020</td>
#                         <td id="T_3fc7d_row3_col1" class="data row3 col1" >2.489933</td>
#                         <td id="T_3fc7d_row3_col2" class="data row3 col2" >2.775758</td>
#                         <td id="T_3fc7d_row3_col3" class="data row3 col3" >3.321622</td>
#             </tr>
#     </tbody></table>

# %%
df = featureAnalysis('F3')
df.style.background_gradient(cmap='Greens',vmin = 0, vmax = 4, axis = None)
# Out:
# <style  type="text/css" >
# #T_575c7_row0_col0{
#             background-color:  #369f54;
#             color:  #000000;
#         }#T_575c7_row0_col1{
#             background-color:  #53b466;
#             color:  #000000;
#         }#T_575c7_row0_col2{
#             background-color:  #40aa5d;
#             color:  #000000;
#         }#T_575c7_row0_col3{
#             background-color:  #58b668;
#             color:  #000000;
#         }#T_575c7_row1_col0{
#             background-color:  #157f3b;
#             color:  #f1f1f1;
#         }#T_575c7_row1_col1{
#             background-color:  #005c25;
#             color:  #f1f1f1;
#         }#T_575c7_row1_col2{
#             background-color:  #218944;
#             color:  #000000;
#         }#T_575c7_row1_col3{
#             background-color:  #1e8741;
#             color:  #000000;
#         }#T_575c7_row2_col0{
#             background-color:  #78c679;
#             color:  #000000;
#         }#T_575c7_row2_col1{
#             background-color:  #9cd797;
#             color:  #000000;
#         }#T_575c7_row2_col2{
#             background-color:  #56b567;
#             color:  #000000;
#         }#T_575c7_row2_col3{
#             background-color:  #afdfa8;
#             color:  #000000;
#         }#T_575c7_row3_col0{
#             background-color:  #63bc6e;
#             color:  #000000;
#         }#T_575c7_row3_col1{
#             background-color:  #48ae60;
#             color:  #000000;
#         }#T_575c7_row3_col2{
#             background-color:  #62bb6d;
#             color:  #000000;
#         }#T_575c7_row3_col3{
#             background-color:  #0b7734;
#             color:  #f1f1f1;
#         }</style><table id="T_575c7_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >typeR</th>        <th class="col_heading level0 col1" >typeE</th>        <th class="col_heading level0 col2" >typeA</th>        <th class="col_heading level0 col3" >typeD</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_575c7_level0_row0" class="row_heading level0 row0" >F3_R</th>
#                         <td id="T_575c7_row0_col0" class="data row0 col0" >2.681373</td>
#                         <td id="T_575c7_row0_col1" class="data row0 col1" >2.318792</td>
#                         <td id="T_575c7_row0_col2" class="data row0 col2" >2.501010</td>
#                         <td id="T_575c7_row0_col3" class="data row0 col3" >2.281081</td>
#             </tr>
#             <tr>
#                         <th id="T_575c7_level0_row1" class="row_heading level0 row1" >F3_E</th>
#                         <td id="T_575c7_row1_col0" class="data row1 col0" >3.191176</td>
#                         <td id="T_575c7_row1_col1" class="data row1 col1" >3.699664</td>
#                         <td id="T_575c7_row1_col2" class="data row1 col2" >3.021212</td>
#                         <td id="T_575c7_row1_col3" class="data row1 col3" >3.064865</td>
#             </tr>
#             <tr>
#                         <th id="T_575c7_level0_row2" class="row_heading level0 row2" >F3_A</th>
#                         <td id="T_575c7_row2_col0" class="data row2 col0" >1.955882</td>
#                         <td id="T_575c7_row2_col1" class="data row2 col1" >1.548658</td>
#                         <td id="T_575c7_row2_col2" class="data row2 col2" >2.290909</td>
#                         <td id="T_575c7_row2_col3" class="data row2 col3" >1.321622</td>
#             </tr>
#             <tr>
#                         <th id="T_575c7_level0_row3" class="row_heading level0 row3" >F3_D</th>
#                         <td id="T_575c7_row3_col0" class="data row3 col0" >2.171569</td>
#                         <td id="T_575c7_row3_col1" class="data row3 col1" >2.432886</td>
#                         <td id="T_575c7_row3_col2" class="data row3 col2" >2.186869</td>
#                         <td id="T_575c7_row3_col3" class="data row3 col3" >3.332432</td>
#             </tr>
#     </tbody></table>

# %%
df = featureAnalysis('F4')
df.style.background_gradient(cmap='Greens',vmin = 0, vmax = 4, axis = None)
# Out:
# <style  type="text/css" >
# #T_363d4_row0_col0{
#             background-color:  #0d7836;
#             color:  #f1f1f1;
#         }#T_363d4_row0_col1,#T_363d4_row1_col3{
#             background-color:  #4bb062;
#             color:  #000000;
#         }#T_363d4_row0_col2{
#             background-color:  #58b668;
#             color:  #000000;
#         }#T_363d4_row0_col3{
#             background-color:  #55b567;
#             color:  #000000;
#         }#T_363d4_row1_col0{
#             background-color:  #4aaf61;
#             color:  #000000;
#         }#T_363d4_row1_col1{
#             background-color:  #1e8741;
#             color:  #000000;
#         }#T_363d4_row1_col2{
#             background-color:  #56b567;
#             color:  #000000;
#         }#T_363d4_row2_col0{
#             background-color:  #8bcf89;
#             color:  #000000;
#         }#T_363d4_row2_col1{
#             background-color:  #9bd696;
#             color:  #000000;
#         }#T_363d4_row2_col2{
#             background-color:  #48ae60;
#             color:  #000000;
#         }#T_363d4_row2_col3{
#             background-color:  #99d595;
#             color:  #000000;
#         }#T_363d4_row3_col0{
#             background-color:  #3fa85b;
#             color:  #000000;
#         }#T_363d4_row3_col1{
#             background-color:  #258d47;
#             color:  #000000;
#         }#T_363d4_row3_col2{
#             background-color:  #228a44;
#             color:  #000000;
#         }#T_363d4_row3_col3{
#             background-color:  #005b25;
#             color:  #f1f1f1;
#         }</style><table id="T_363d4_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >typeR</th>        <th class="col_heading level0 col1" >typeE</th>        <th class="col_heading level0 col2" >typeA</th>        <th class="col_heading level0 col3" >typeD</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_363d4_level0_row0" class="row_heading level0 row0" >F4_R</th>
#                         <td id="T_363d4_row0_col0" class="data row0 col0" >3.303922</td>
#                         <td id="T_363d4_row0_col1" class="data row0 col1" >2.395973</td>
#                         <td id="T_363d4_row0_col2" class="data row0 col2" >2.280808</td>
#                         <td id="T_363d4_row0_col3" class="data row0 col3" >2.302703</td>
#             </tr>
#             <tr>
#                         <th id="T_363d4_level0_row1" class="row_heading level0 row1" >F4_E</th>
#                         <td id="T_363d4_row1_col0" class="data row1 col0" >2.411765</td>
#                         <td id="T_363d4_row1_col1" class="data row1 col1" >3.073826</td>
#                         <td id="T_363d4_row1_col2" class="data row1 col2" >2.291919</td>
#                         <td id="T_363d4_row1_col3" class="data row1 col3" >2.394595</td>
#             </tr>
#             <tr>
#                         <th id="T_363d4_level0_row2" class="row_heading level0 row2" >F4_A</th>
#                         <td id="T_363d4_row2_col0" class="data row2 col0" >1.745098</td>
#                         <td id="T_363d4_row2_col1" class="data row2 col1" >1.567114</td>
#                         <td id="T_363d4_row2_col2" class="data row2 col2" >2.422222</td>
#                         <td id="T_363d4_row2_col3" class="data row2 col3" >1.591892</td>
#             </tr>
#             <tr>
#                         <th id="T_363d4_level0_row3" class="row_heading level0 row3" >F4_D</th>
#                         <td id="T_363d4_row3_col0" class="data row3 col0" >2.539216</td>
#                         <td id="T_363d4_row3_col1" class="data row3 col1" >2.963087</td>
#                         <td id="T_363d4_row3_col2" class="data row3 col2" >3.005051</td>
#                         <td id="T_363d4_row3_col3" class="data row3 col3" >3.710811</td>
#             </tr>
#     </tbody></table>

# %%
df = featureAnalysis('F5')
df.style.background_gradient(cmap='Greens',vmin = 0, vmax = 4, axis = None)
# Out:
# <style  type="text/css" >
# #T_9dcf2_row0_col0{
#             background-color:  #006227;
#             color:  #f1f1f1;
#         }#T_9dcf2_row0_col1{
#             background-color:  #3fa85b;
#             color:  #000000;
#         }#T_9dcf2_row0_col2{
#             background-color:  #4bb062;
#             color:  #000000;
#         }#T_9dcf2_row0_col3{
#             background-color:  #80ca80;
#             color:  #000000;
#         }#T_9dcf2_row1_col0{
#             background-color:  #2d954d;
#             color:  #000000;
#         }#T_9dcf2_row1_col1{
#             background-color:  #005924;
#             color:  #f1f1f1;
#         }#T_9dcf2_row1_col2{
#             background-color:  #1c8540;
#             color:  #000000;
#         }#T_9dcf2_row1_col3{
#             background-color:  #026f2e;
#             color:  #f1f1f1;
#         }#T_9dcf2_row2_col0,#T_9dcf2_row2_col1{
#             background-color:  #5ab769;
#             color:  #000000;
#         }#T_9dcf2_row2_col2{
#             background-color:  #2c944c;
#             color:  #000000;
#         }#T_9dcf2_row2_col3{
#             background-color:  #58b668;
#             color:  #000000;
#         }#T_9dcf2_row3_col0{
#             background-color:  #b1e0ab;
#             color:  #000000;
#         }#T_9dcf2_row3_col1{
#             background-color:  #a4da9e;
#             color:  #000000;
#         }#T_9dcf2_row3_col2{
#             background-color:  #92d28f;
#             color:  #000000;
#         }#T_9dcf2_row3_col3{
#             background-color:  #4aaf61;
#             color:  #000000;
#         }</style><table id="T_9dcf2_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >typeR</th>        <th class="col_heading level0 col1" >typeE</th>        <th class="col_heading level0 col2" >typeA</th>        <th class="col_heading level0 col3" >typeD</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_9dcf2_level0_row0" class="row_heading level0 row0" >F5_R</th>
#                         <td id="T_9dcf2_row0_col0" class="data row0 col0" >3.637255</td>
#                         <td id="T_9dcf2_row0_col1" class="data row0 col1" >2.538591</td>
#                         <td id="T_9dcf2_row0_col2" class="data row0 col2" >2.403030</td>
#                         <td id="T_9dcf2_row0_col3" class="data row0 col3" >1.862162</td>
#             </tr>
#             <tr>
#                         <th id="T_9dcf2_level0_row1" class="row_heading level0 row1" >F5_E</th>
#                         <td id="T_9dcf2_row1_col0" class="data row1 col0" >2.828431</td>
#                         <td id="T_9dcf2_row1_col1" class="data row1 col1" >3.734899</td>
#                         <td id="T_9dcf2_row1_col2" class="data row1 col2" >3.093939</td>
#                         <td id="T_9dcf2_row1_col3" class="data row1 col3" >3.454054</td>
#             </tr>
#             <tr>
#                         <th id="T_9dcf2_level0_row2" class="row_heading level0 row2" >F5_A</th>
#                         <td id="T_9dcf2_row2_col0" class="data row2 col0" >2.250000</td>
#                         <td id="T_9dcf2_row2_col1" class="data row2 col1" >2.265101</td>
#                         <td id="T_9dcf2_row2_col2" class="data row2 col2" >2.845455</td>
#                         <td id="T_9dcf2_row2_col3" class="data row2 col3" >2.267568</td>
#             </tr>
#             <tr>
#                         <th id="T_9dcf2_level0_row3" class="row_heading level0 row3" >F5_D</th>
#                         <td id="T_9dcf2_row3_col0" class="data row3 col0" >1.284314</td>
#                         <td id="T_9dcf2_row3_col1" class="data row3 col1" >1.461409</td>
#                         <td id="T_9dcf2_row3_col2" class="data row3 col2" >1.657576</td>
#                         <td id="T_9dcf2_row3_col3" class="data row3 col3" >2.416216</td>
#             </tr>
#     </tbody></table>

# %%
df = featureAnalysis('F6')
df.style.background_gradient(cmap='Greens',vmin = 0, vmax = 4, axis = None)
# Out:
# <style  type="text/css" >
# #T_04e6b_row0_col0{
#             background-color:  #107a37;
#             color:  #f1f1f1;
#         }#T_04e6b_row0_col1,#T_04e6b_row0_col2{
#             background-color:  #75c477;
#             color:  #000000;
#         }#T_04e6b_row0_col3{
#             background-color:  #8ace88;
#             color:  #000000;
#         }#T_04e6b_row1_col0{
#             background-color:  #3aa357;
#             color:  #000000;
#         }#T_04e6b_row1_col1{
#             background-color:  #0b7734;
#             color:  #f1f1f1;
#         }#T_04e6b_row1_col2{
#             background-color:  #45ad5f;
#             color:  #000000;
#         }#T_04e6b_row1_col3{
#             background-color:  #3ea75a;
#             color:  #000000;
#         }#T_04e6b_row2_col0{
#             background-color:  #81ca81;
#             color:  #000000;
#         }#T_04e6b_row2_col1{
#             background-color:  #92d28f;
#             color:  #000000;
#         }#T_04e6b_row2_col2{
#             background-color:  #42ab5d;
#             color:  #000000;
#         }#T_04e6b_row2_col3{
#             background-color:  #76c578;
#             color:  #000000;
#         }#T_04e6b_row3_col0{
#             background-color:  #5ab769;
#             color:  #000000;
#         }#T_04e6b_row3_col1{
#             background-color:  #228a44;
#             color:  #000000;
#         }#T_04e6b_row3_col2{
#             background-color:  #208843;
#             color:  #000000;
#         }#T_04e6b_row3_col3{
#             background-color:  #005c25;
#             color:  #f1f1f1;
#         }</style><table id="T_04e6b_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >typeR</th>        <th class="col_heading level0 col1" >typeE</th>        <th class="col_heading level0 col2" >typeA</th>        <th class="col_heading level0 col3" >typeD</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_04e6b_level0_row0" class="row_heading level0 row0" >F6_R</th>
#                         <td id="T_04e6b_row0_col0" class="data row0 col0" >3.274510</td>
#                         <td id="T_04e6b_row0_col1" class="data row0 col1" >1.991611</td>
#                         <td id="T_04e6b_row0_col2" class="data row0 col2" >1.996970</td>
#                         <td id="T_04e6b_row0_col3" class="data row0 col3" >1.762162</td>
#             </tr>
#             <tr>
#                         <th id="T_04e6b_level0_row1" class="row_heading level0 row1" >F6_E</th>
#                         <td id="T_04e6b_row1_col0" class="data row1 col0" >2.617647</td>
#                         <td id="T_04e6b_row1_col1" class="data row1 col1" >3.338926</td>
#                         <td id="T_04e6b_row1_col2" class="data row1 col2" >2.465657</td>
#                         <td id="T_04e6b_row1_col3" class="data row1 col3" >2.551351</td>
#             </tr>
#             <tr>
#                         <th id="T_04e6b_level0_row2" class="row_heading level0 row2" >F6_A</th>
#                         <td id="T_04e6b_row2_col0" class="data row2 col0" >1.848039</td>
#                         <td id="T_04e6b_row2_col1" class="data row2 col1" >1.664430</td>
#                         <td id="T_04e6b_row2_col2" class="data row2 col2" >2.496970</td>
#                         <td id="T_04e6b_row2_col3" class="data row2 col3" >1.983784</td>
#             </tr>
#             <tr>
#                         <th id="T_04e6b_level0_row3" class="row_heading level0 row3" >F6_D</th>
#                         <td id="T_04e6b_row3_col0" class="data row3 col0" >2.259804</td>
#                         <td id="T_04e6b_row3_col1" class="data row3 col1" >3.005034</td>
#                         <td id="T_04e6b_row3_col2" class="data row3 col2" >3.040404</td>
#                         <td id="T_04e6b_row3_col3" class="data row3 col3" >3.702703</td>
#             </tr>
#     </tbody></table>

# %%
df = featureAnalysis('F6')
df.style.background_gradient(cmap='Greens',vmin = 0, vmax = 4, axis = None)
# Out:
# <style  type="text/css" >
# #T_bda1a_row0_col0{
#             background-color:  #107a37;
#             color:  #f1f1f1;
#         }#T_bda1a_row0_col1,#T_bda1a_row0_col2{
#             background-color:  #75c477;
#             color:  #000000;
#         }#T_bda1a_row0_col3{
#             background-color:  #8ace88;
#             color:  #000000;
#         }#T_bda1a_row1_col0{
#             background-color:  #3aa357;
#             color:  #000000;
#         }#T_bda1a_row1_col1{
#             background-color:  #0b7734;
#             color:  #f1f1f1;
#         }#T_bda1a_row1_col2{
#             background-color:  #45ad5f;
#             color:  #000000;
#         }#T_bda1a_row1_col3{
#             background-color:  #3ea75a;
#             color:  #000000;
#         }#T_bda1a_row2_col0{
#             background-color:  #81ca81;
#             color:  #000000;
#         }#T_bda1a_row2_col1{
#             background-color:  #92d28f;
#             color:  #000000;
#         }#T_bda1a_row2_col2{
#             background-color:  #42ab5d;
#             color:  #000000;
#         }#T_bda1a_row2_col3{
#             background-color:  #76c578;
#             color:  #000000;
#         }#T_bda1a_row3_col0{
#             background-color:  #5ab769;
#             color:  #000000;
#         }#T_bda1a_row3_col1{
#             background-color:  #228a44;
#             color:  #000000;
#         }#T_bda1a_row3_col2{
#             background-color:  #208843;
#             color:  #000000;
#         }#T_bda1a_row3_col3{
#             background-color:  #005c25;
#             color:  #f1f1f1;
#         }</style><table id="T_bda1a_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >typeR</th>        <th class="col_heading level0 col1" >typeE</th>        <th class="col_heading level0 col2" >typeA</th>        <th class="col_heading level0 col3" >typeD</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_bda1a_level0_row0" class="row_heading level0 row0" >F6_R</th>
#                         <td id="T_bda1a_row0_col0" class="data row0 col0" >3.274510</td>
#                         <td id="T_bda1a_row0_col1" class="data row0 col1" >1.991611</td>
#                         <td id="T_bda1a_row0_col2" class="data row0 col2" >1.996970</td>
#                         <td id="T_bda1a_row0_col3" class="data row0 col3" >1.762162</td>
#             </tr>
#             <tr>
#                         <th id="T_bda1a_level0_row1" class="row_heading level0 row1" >F6_E</th>
#                         <td id="T_bda1a_row1_col0" class="data row1 col0" >2.617647</td>
#                         <td id="T_bda1a_row1_col1" class="data row1 col1" >3.338926</td>
#                         <td id="T_bda1a_row1_col2" class="data row1 col2" >2.465657</td>
#                         <td id="T_bda1a_row1_col3" class="data row1 col3" >2.551351</td>
#             </tr>
#             <tr>
#                         <th id="T_bda1a_level0_row2" class="row_heading level0 row2" >F6_A</th>
#                         <td id="T_bda1a_row2_col0" class="data row2 col0" >1.848039</td>
#                         <td id="T_bda1a_row2_col1" class="data row2 col1" >1.664430</td>
#                         <td id="T_bda1a_row2_col2" class="data row2 col2" >2.496970</td>
#                         <td id="T_bda1a_row2_col3" class="data row2 col3" >1.983784</td>
#             </tr>
#             <tr>
#                         <th id="T_bda1a_level0_row3" class="row_heading level0 row3" >F6_D</th>
#                         <td id="T_bda1a_row3_col0" class="data row3 col0" >2.259804</td>
#                         <td id="T_bda1a_row3_col1" class="data row3 col1" >3.005034</td>
#                         <td id="T_bda1a_row3_col2" class="data row3 col2" >3.040404</td>
#                         <td id="T_bda1a_row3_col3" class="data row3 col3" >3.702703</td>
#             </tr>
#     </tbody></table>

# %%
df = featureAnalysis('F7')
df.style.background_gradient(cmap='Greens',vmin = 0, vmax = 4, axis = None)
# Out:
# <style  type="text/css" >
# #T_b4267_row0_col0{
#             background-color:  #087432;
#             color:  #f1f1f1;
#         }#T_b4267_row0_col1{
#             background-color:  #68be70;
#             color:  #000000;
#         }#T_b4267_row0_col2{
#             background-color:  #4aaf61;
#             color:  #000000;
#         }#T_b4267_row0_col3{
#             background-color:  #73c476;
#             color:  #000000;
#         }#T_b4267_row1_col0{
#             background-color:  #66bd6f;
#             color:  #000000;
#         }#T_b4267_row1_col1{
#             background-color:  #1e8741;
#             color:  #000000;
#         }#T_b4267_row1_col2,#T_b4267_row2_col1{
#             background-color:  #72c375;
#             color:  #000000;
#         }#T_b4267_row1_col3,#T_b4267_row3_col0{
#             background-color:  #70c274;
#             color:  #000000;
#         }#T_b4267_row2_col0{
#             background-color:  #46ae60;
#             color:  #000000;
#         }#T_b4267_row2_col2{
#             background-color:  #289049;
#             color:  #000000;
#         }#T_b4267_row2_col3{
#             background-color:  #50b264;
#             color:  #000000;
#         }#T_b4267_row3_col1{
#             background-color:  #2f984f;
#             color:  #000000;
#         }#T_b4267_row3_col2{
#             background-color:  #38a156;
#             color:  #000000;
#         }#T_b4267_row3_col3{
#             background-color:  #006428;
#             color:  #f1f1f1;
#         }</style><table id="T_b4267_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >typeR</th>        <th class="col_heading level0 col1" >typeE</th>        <th class="col_heading level0 col2" >typeA</th>        <th class="col_heading level0 col3" >typeD</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b4267_level0_row0" class="row_heading level0 row0" >F7_R</th>
#                         <td id="T_b4267_row0_col0" class="data row0 col0" >3.387255</td>
#                         <td id="T_b4267_row0_col1" class="data row0 col1" >2.117450</td>
#                         <td id="T_b4267_row0_col2" class="data row0 col2" >2.407071</td>
#                         <td id="T_b4267_row0_col3" class="data row0 col3" >2.002703</td>
#             </tr>
#             <tr>
#                         <th id="T_b4267_level0_row1" class="row_heading level0 row1" >F7_E</th>
#                         <td id="T_b4267_row1_col0" class="data row1 col0" >2.132353</td>
#                         <td id="T_b4267_row1_col1" class="data row1 col1" >3.063758</td>
#                         <td id="T_b4267_row1_col2" class="data row1 col2" >2.029293</td>
#                         <td id="T_b4267_row1_col3" class="data row1 col3" >2.037838</td>
#             </tr>
#             <tr>
#                         <th id="T_b4267_level0_row2" class="row_heading level0 row2" >F7_A</th>
#                         <td id="T_b4267_row2_col0" class="data row2 col0" >2.441176</td>
#                         <td id="T_b4267_row2_col1" class="data row2 col1" >2.026846</td>
#                         <td id="T_b4267_row2_col2" class="data row2 col2" >2.909091</td>
#                         <td id="T_b4267_row2_col3" class="data row2 col3" >2.351351</td>
#             </tr>
#             <tr>
#                         <th id="T_b4267_level0_row3" class="row_heading level0 row3" >F7_D</th>
#                         <td id="T_b4267_row3_col0" class="data row3 col0" >2.039216</td>
#                         <td id="T_b4267_row3_col1" class="data row3 col1" >2.791946</td>
#                         <td id="T_b4267_row3_col2" class="data row3 col2" >2.654545</td>
#                         <td id="T_b4267_row3_col3" class="data row3 col3" >3.608108</td>
#             </tr>
#     </tbody></table>

# %%
df = featureAnalysis('F8')
df.style.background_gradient(cmap='Greens',vmin = 0, vmax = 4, axis = None)
# Out:
# <style  type="text/css" >
# #T_2579a_row0_col0{
#             background-color:  #278f48;
#             color:  #000000;
#         }#T_2579a_row0_col1{
#             background-color:  #5eb96b;
#             color:  #000000;
#         }#T_2579a_row0_col2{
#             background-color:  #75c477;
#             color:  #000000;
#         }#T_2579a_row0_col3{
#             background-color:  #7dc87e;
#             color:  #000000;
#         }#T_2579a_row1_col0{
#             background-color:  #127c39;
#             color:  #f1f1f1;
#         }#T_2579a_row1_col1{
#             background-color:  #005622;
#             color:  #f1f1f1;
#         }#T_2579a_row1_col2{
#             background-color:  #107a37;
#             color:  #f1f1f1;
#         }#T_2579a_row1_col3{
#             background-color:  #077331;
#             color:  #f1f1f1;
#         }#T_2579a_row2_col0{
#             background-color:  #99d595;
#             color:  #000000;
#         }#T_2579a_row2_col1{
#             background-color:  #a5db9f;
#             color:  #000000;
#         }#T_2579a_row2_col2{
#             background-color:  #72c375;
#             color:  #000000;
#         }#T_2579a_row2_col3{
#             background-color:  #97d492;
#             color:  #000000;
#         }#T_2579a_row3_col0{
#             background-color:  #5ab769;
#             color:  #000000;
#         }#T_2579a_row3_col1{
#             background-color:  #3ea75a;
#             color:  #000000;
#         }#T_2579a_row3_col2{
#             background-color:  #339c52;
#             color:  #000000;
#         }#T_2579a_row3_col3{
#             background-color:  #1c8540;
#             color:  #000000;
#         }</style><table id="T_2579a_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >typeR</th>        <th class="col_heading level0 col1" >typeE</th>        <th class="col_heading level0 col2" >typeA</th>        <th class="col_heading level0 col3" >typeD</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_2579a_level0_row0" class="row_heading level0 row0" >F8_R</th>
#                         <td id="T_2579a_row0_col0" class="data row0 col0" >2.931373</td>
#                         <td id="T_2579a_row0_col1" class="data row0 col1" >2.209732</td>
#                         <td id="T_2579a_row0_col2" class="data row0 col2" >1.990909</td>
#                         <td id="T_2579a_row0_col3" class="data row0 col3" >1.900000</td>
#             </tr>
#             <tr>
#                         <th id="T_2579a_level0_row1" class="row_heading level0 row1" >F8_E</th>
#                         <td id="T_2579a_row1_col0" class="data row1 col0" >3.235294</td>
#                         <td id="T_2579a_row1_col1" class="data row1 col1" >3.780201</td>
#                         <td id="T_2579a_row1_col2" class="data row1 col2" >3.269697</td>
#                         <td id="T_2579a_row1_col3" class="data row1 col3" >3.391892</td>
#             </tr>
#             <tr>
#                         <th id="T_2579a_level0_row2" class="row_heading level0 row2" >F8_A</th>
#                         <td id="T_2579a_row2_col0" class="data row2 col0" >1.578431</td>
#                         <td id="T_2579a_row2_col1" class="data row2 col1" >1.449664</td>
#                         <td id="T_2579a_row2_col2" class="data row2 col2" >2.020202</td>
#                         <td id="T_2579a_row2_col3" class="data row2 col3" >1.610811</td>
#             </tr>
#             <tr>
#                         <th id="T_2579a_level0_row3" class="row_heading level0 row3" >F8_D</th>
#                         <td id="T_2579a_row3_col0" class="data row3 col0" >2.254902</td>
#                         <td id="T_2579a_row3_col1" class="data row3 col1" >2.560403</td>
#                         <td id="T_2579a_row3_col2" class="data row3 col2" >2.719192</td>
#                         <td id="T_2579a_row3_col3" class="data row3 col3" >3.097297</td>
#             </tr>
#     </tbody></table>

# %%
df = featureAnalysis('F9')
df.style.background_gradient(cmap='Greens',vmin = 0, vmax = 4, axis = None)
# Out:
# <style  type="text/css" >
# #T_e781a_row0_col0{
#             background-color:  #268e47;
#             color:  #000000;
#         }#T_e781a_row0_col1{
#             background-color:  #9fd899;
#             color:  #000000;
#         }#T_e781a_row0_col2{
#             background-color:  #81ca81;
#             color:  #000000;
#         }#T_e781a_row0_col3{
#             background-color:  #acdea6;
#             color:  #000000;
#         }#T_e781a_row1_col0{
#             background-color:  #369f54;
#             color:  #000000;
#         }#T_e781a_row1_col1{
#             background-color:  #006c2c;
#             color:  #f1f1f1;
#         }#T_e781a_row1_col2{
#             background-color:  #359e53;
#             color:  #000000;
#         }#T_e781a_row1_col3{
#             background-color:  #319a50;
#             color:  #000000;
#         }#T_e781a_row2_col0{
#             background-color:  #3ba458;
#             color:  #000000;
#         }#T_e781a_row2_col1,#T_e781a_row2_col3{
#             background-color:  #349d53;
#             color:  #000000;
#         }#T_e781a_row2_col2{
#             background-color:  #127c39;
#             color:  #f1f1f1;
#         }#T_e781a_row3_col0{
#             background-color:  #88ce87;
#             color:  #000000;
#         }#T_e781a_row3_col1{
#             background-color:  #5ab769;
#             color:  #000000;
#         }#T_e781a_row3_col2{
#             background-color:  #5eb96b;
#             color:  #000000;
#         }#T_e781a_row3_col3{
#             background-color:  #16803c;
#             color:  #f1f1f1;
#         }</style><table id="T_e781a_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >typeR</th>        <th class="col_heading level0 col1" >typeE</th>        <th class="col_heading level0 col2" >typeA</th>        <th class="col_heading level0 col3" >typeD</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e781a_level0_row0" class="row_heading level0 row0" >F9_R</th>
#                         <td id="T_e781a_row0_col0" class="data row0 col0" >2.946078</td>
#                         <td id="T_e781a_row0_col1" class="data row0 col1" >1.516779</td>
#                         <td id="T_e781a_row0_col2" class="data row0 col2" >1.847475</td>
#                         <td id="T_e781a_row0_col3" class="data row0 col3" >1.351351</td>
#             </tr>
#             <tr>
#                         <th id="T_e781a_level0_row1" class="row_heading level0 row1" >F9_E</th>
#                         <td id="T_e781a_row1_col0" class="data row1 col0" >2.681373</td>
#                         <td id="T_e781a_row1_col1" class="data row1 col1" >3.510067</td>
#                         <td id="T_e781a_row1_col2" class="data row1 col2" >2.695960</td>
#                         <td id="T_e781a_row1_col3" class="data row1 col3" >2.756757</td>
#             </tr>
#             <tr>
#                         <th id="T_e781a_level0_row2" class="row_heading level0 row2" >F9_A</th>
#                         <td id="T_e781a_row2_col0" class="data row2 col0" >2.602941</td>
#                         <td id="T_e781a_row2_col1" class="data row2 col1" >2.713087</td>
#                         <td id="T_e781a_row2_col2" class="data row2 col2" >3.243434</td>
#                         <td id="T_e781a_row2_col3" class="data row2 col3" >2.708108</td>
#             </tr>
#             <tr>
#                         <th id="T_e781a_level0_row3" class="row_heading level0 row3" >F9_D</th>
#                         <td id="T_e781a_row3_col0" class="data row3 col0" >1.769608</td>
#                         <td id="T_e781a_row3_col1" class="data row3 col1" >2.260067</td>
#                         <td id="T_e781a_row3_col2" class="data row3 col2" >2.213131</td>
#                         <td id="T_e781a_row3_col3" class="data row3 col3" >3.183784</td>
#             </tr>
#     </tbody></table>
